# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=
# %env CLEARML_API_SECRET_KEY=
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=
# env: CLEARML_API_SECRET_KEY=

# %%
from clearml import Task
from ultralytics import YOLO

task = Task.init(project_name='Team 10', task_name='tune experiment', tags=['YOLOv8', 'hyperparameters'])

model = YOLO('yolov8n.pt')
results = model.tune(data='./datasets/swedish_signs/yolo_annotations_SwedishSigns.yaml', epochs=30, iterations=300, imgsz=640, plots=False, save=False, val=False)
print('Finish tuning')
# Out:
# ClearML Task: overwriting (reusing) task id=4bbdd29408a841e88032d75fa3ce5888
# 2023-11-28 09:50:01,977 - clearml.Repository Detection - WARNING - Could not read Jupyter Notebook: No module named 'nbconvert'
# 2023-11-28 09:50:01,978 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/3e1bc25f4999483abd193d50661626dc/experiments/4bbdd29408a841e88032d75fa3ce5888/output/log
# 2023-11-28 09:50:05,178 - clearml.model - INFO - Selected model id: be8ff86439664d648bce47a8de373613
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune3'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# ...
